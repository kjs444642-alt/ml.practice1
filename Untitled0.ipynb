# %% [markdown]
# <a href="https://colab.research.google.com/github/kjs444642-alt/ml.practice1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #나의 첫 번째 코랩
# ##실습 내용
# -실습1: Google의 Folab으로 첫 번재  파일 생성
#
# -실습2: Git 레포지토리 생성
#
# -실습3: Colab 제공 기능으로 Github에 업로드하기

# %% [markdown]
# #1.Hello Wolrd 출력하기
# - print 함수 사용

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# #2. Tensorflow 모듈 불러오기

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.19.0'
